# %%
import pandas as pd

df = pd.read_csv("../data/iran_us_memes.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("../data/iran_us_memes.csv")
#       4 df.head()
#
# File ~/war-memes-project/venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
# !pwd
# Out:
# /Users/elifhazalgougler/war-memes-project

# %%
# !ls
# Out:
# Untitled.ipynb data           notebooks      outputs        venv

# %%
import pandas as pd

df = pd.read_csv("data/iran_us_memes.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("data/iran_us_memes.csv")
#       4 df.head()
#
# File ~/war-memes-project/venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
# !ls data
# Out:
# data:iran_us_memes.csv

# %%
import pandas as pd

df = pd.read_csv("data/data:iran_us_memes.csv")
df.head()
# Out:
#    id                                text (post_caption)  \
# 0   1  Iranian media mocks Trump with viral meme abou...
# 1   2               Iranian trolling is getting too good
# 2   3  I made a meme about Iran and you better all li...
# 3   4  When you don’t want to get involved in another...
# 4   5  Iranians are frustrated that Israel didn't att...
#
#                                            meme_text  \
# 0                                 Controlling Hormuz
# 1                                    (no clear text)
# 2  I made a meme about Iran and you better all li...
# 3                                  (same as caption)
# 4                                    (no clear text)
#
#                 caption_theme                      meme_theme  \
# 0      framing, amplification             satire, geopolitics
# 1   admiration, amplification        satire, power, exclusion
# 2     self-referential, humor     satire, absurdity, conflict
# ...

# %%
df.shape
# Out:
# (31, 7)

# %%
df
# Out:
#     id                                text (post_caption)  \
# 0    1  Iranian media mocks Trump with viral meme abou...
# 1    2               Iranian trolling is getting too good
# 2    3  I made a meme about Iran and you better all li...
# 3    4  When you don’t want to get involved in another...
# 4    5  Iranians are frustrated that Israel didn't att...
# 5    6  The Iranian Air Force prepping to mobilize the...
# 6    7  Third worlders watching America obliterate Ira...
# 7    8  A message to the U.S. Military about to fight ...
# 8    9                      This sums up the USA-Iran war
# 9   11                                       (no caption)
# 10  12                                       (no caption)
# 11  13                                       (no caption)
# 12  14      Saudi Arabia wins the humiliation meme so far
# 13  15                                       (no caption)
# 14  16    This meme is viral and rightfully so #ceasefire
# ...

# %%
df["caption_theme"].value_counts()
# Out:
# caption_theme
# neutral                                 2
# evaluative framing                      2
# satirical framing                       2
# satire, mockery                         2
# framing, amplification                  1
# admiration, amplification               1
# self-referential, humor                 1
# analytical framing                      1
# descriptive, amplification              1
# neutral, humor                          1
# framing                                 1
# mobilization, propaganda                1
# framing, emotional                      1
# critical framing                        1
# critical                                1
# endorsement, activism                   1
# endorsement, framing                    1
# ideological framing, advocacy           1
# personal framing, critique              1
# humor, exaggeration                     1
# propaganda, mockery                     1
# reaction, amplification                 1
# ...

# %%
df["caption_theme"].value_counts().plot(kind="bar")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: xlabel='caption_theme'>

# %%
df["main_theme"] = df["caption_theme"].apply(lambda x: x.split(",")[0])

# %%
df[["caption_theme", "main_theme"]].head()
# Out:
#                 caption_theme          main_theme
# 0      framing, amplification             framing
# 1   admiration, amplification          admiration
# 2     self-referential, humor    self-referential
# 3          analytical framing  analytical framing
# 4  descriptive, amplification         descriptive

# %%
df["main_theme"].value_counts()
# Out:
# main_theme
# framing                3
# neutral                3
# satire                 3
# critical framing       2
# evaluative framing     2
# endorsement            2
# satirical framing      2
# admiration             1
# self-referential       1
# analytical framing     1
# descriptive            1
# mobilization           1
# critical               1
# ideological framing    1
# personal framing       1
# humor                  1
# propaganda             1
# reaction               1
# commentary             1
# irony                  1
# provocative framing    1
# Name: count, dtype: int64

# %%
df["main_theme"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='main_theme'>

# %%
df["main_theme"] = df["caption_theme"].apply(lambda x: x.split(",")[0].split()[0])

# %%
df["main_theme"].value_counts()
# Out:
# main_theme
# framing             3
# neutral             3
# critical            3
# satire              3
# evaluative          2
# endorsement         2
# satirical           2
# admiration          1
# self-referential    1
# analytical          1
# descriptive         1
# mobilization        1
# ideological         1
# personal            1
# humor               1
# propaganda          1
# reaction            1
# commentary          1
# irony               1
# provocative         1
# Name: count, dtype: int64

# %%
df["main_theme"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='main_theme'>

# %%
df["main_theme"].value_counts()
# Out:
# main_theme
# framing             3
# neutral             3
# critical            3
# satire              3
# evaluative          2
# endorsement         2
# satirical           2
# admiration          1
# self-referential    1
# analytical          1
# descriptive         1
# mobilization        1
# ideological         1
# personal            1
# humor               1
# propaganda          1
# reaction            1
# commentary          1
# irony               1
# provocative         1
# Name: count, dtype: int64

# %%
pd.crosstab(df["main_theme"], df["meme_theme"])
# Out:
# meme_theme        absurdity, delay, war reference, satire  \
# main_theme
# admiration                                              0
# analytical                                              0
# commentary                                              0
# critical                                                0
# descriptive                                             0
# endorsement                                             0
# evaluative                                              0
# framing                                                 0
# humor                                                   1
# ideological                                             0
# irony                                                   0
# mobilization                                            0
# neutral                                                 0
# personal                                                0
# propaganda                                              0
# ...

# %%
df["main_meme_theme"] = df["meme_theme"].apply(lambda x: x.split(",")[0])

# %%
pd.crosstab(df["main_theme"], df["main_meme_theme"])
# Out:
# main_meme_theme   absurdity  dark humor  geopolitics  humor  \
# main_theme
# admiration                0           0            0      0
# analytical                0           0            1      0
# commentary                0           0            1      0
# critical                  0           0            2      0
# descriptive               0           0            0      0
# endorsement               0           0            2      0
# evaluative                0           0            2      0
# framing                   0           0            0      0
# humor                     1           0            0      0
# ideological               0           0            1      0
# irony                     0           0            1      0
# mobilization              0           0            0      0
# neutral                   0           0            0      2
# personal                  0           0            1      0
# ...

# %%
# %matplotlib inline

import seaborn as sns
import matplotlib.pyplot as plt

ct = pd.crosstab(df["main_theme"], df["main_meme_theme"])

plt.figure(figsize=(10,6))

sns.heatmap(
    ct,
    annot=True,
    fmt="d",
    cmap="Blues",
    linewidths=0.5
)

plt.title("Relationship Between Caption Themes and Meme Themes")
plt.xlabel("Meme Theme")
plt.ylabel("Caption Theme")

plt.xticks(rotation=45)
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2
#       3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 ct = pd.crosstab(df["main_theme"], df["main_meme_theme"])
#       7
#       8 plt.figure(figsize=(10,6))
#       9
#
# NameError: name 'pd' is not defined

# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

ct = pd.crosstab(df["main_theme"], df["main_meme_theme"])

plt.figure(figsize=(10,6))

sns.heatmap(
    ct,
    annot=True,
    fmt="d",
    cmap="Blues",
    linewidths=0.5
)

plt.title("Relationship Between Caption Themes and Meme Themes")
plt.xlabel("Meme Theme")
plt.ylabel("Caption Theme")

plt.xticks(rotation=45)
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 import pandas as pd
#       4 import seaborn as sns
#       5 import matplotlib.pyplot as plt
#       6
# ----> 7 ct = pd.crosstab(df["main_theme"], df["main_meme_theme"])
#       8
#       9 plt.figure(figsize=(10,6))
#      10
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv("data/data:iran_us_memes.csv")
df.head()
# Out:
#    id                                text (post_caption)  \
# 0   1  Iranian media mocks Trump with viral meme abou...
# 1   2               Iranian trolling is getting too good
# 2   3  I made a meme about Iran and you better all li...
# 3   4  When you don’t want to get involved in another...
# 4   5  Iranians are frustrated that Israel didn't att...
#
#                                            meme_text  \
# 0                                 Controlling Hormuz
# 1                                    (no clear text)
# 2  I made a meme about Iran and you better all li...
# 3                                  (same as caption)
# 4                                    (no clear text)
#
#                 caption_theme                      meme_theme  \
# 0      framing, amplification             satire, geopolitics
# 1   admiration, amplification        satire, power, exclusion
# 2     self-referential, humor     satire, absurdity, conflict
# ...

# %%
df.shape
# Out:
# (31, 7)

# %%
import pandas as pd

df = pd.read_csv("data/data:iran_us_memes.csv")

print(df.shape)
df
# Out:
# (31, 7)
#     id                                text (post_caption)  \
# 0    1  Iranian media mocks Trump with viral meme abou...
# 1    2               Iranian trolling is getting too good
# 2    3  I made a meme about Iran and you better all li...
# 3    4  When you don’t want to get involved in another...
# 4    5  Iranians are frustrated that Israel didn't att...
# 5    6  The Iranian Air Force prepping to mobilize the...
# 6    7  Third worlders watching America obliterate Ira...
# 7    8  A message to the U.S. Military about to fight ...
# 8    9                      This sums up the USA-Iran war
# 9   11                                       (no caption)
# 10  12                                       (no caption)
# 11  13                                       (no caption)
# 12  14      Saudi Arabia wins the humiliation meme so far
# 13  15                                       (no caption)
# 14  16    This meme is viral and rightfully so #ceasefire
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

ct = pd.crosstab(df["main_theme"], df["main_meme_theme"])

plt.figure(figsize=(12,7))

sns.heatmap(
    ct,
    annot=True,
    fmt="d",
    cmap="Blues",
    linewidths=0.5
)

plt.title("Caption Themes vs Meme Themes")
plt.xlabel("Meme Theme")
plt.ylabel("Caption Theme")

plt.xticks(rotation=45)
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/war-memes-project/venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df["main_theme"] = df["caption_theme"].apply(lambda x: x.split(",")[0])

# %%
df["main_theme"] = df["caption_theme"].apply(lambda x: x.split(",")[0])

# %%
df["main_meme_theme"] = df["meme_theme"].apply(lambda x: x.split(",")[0])

# %%
ct = pd.crosstab(df["main_theme"], df["main_meme_theme"])

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,7))

sns.heatmap(ct, annot=True, fmt="d", cmap="Blues")

plt.show()

# %%
# preprocessing
df["main_theme"] = df["caption_theme"].apply(lambda x: x.split(",")[0])
df["main_meme_theme"] = df["meme_theme"].apply(lambda x: x.split(",")[0])

# %%
ct_norm = ct.div(ct.sum(axis=1), axis=0)

sns.heatmap(ct_norm, annot=True, cmap="Blues")
# Out:
# <Axes: xlabel='main_meme_theme', ylabel='main_theme'>

# %%
plt.savefig("outputs/heatmap.png")

# %%
git add .
git commit -m "add heatmap"
git push
# Out:
#   Cell In[14], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax

# %%
import os

os.makedirs("outputs", exist_ok=True)

plt.savefig("outputs/heatmap.png")

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image, display

os.makedirs("outputs", exist_ok=True)

df = pd.read_csv("data/data:iran_us_memes.csv")

df["main_theme"] = df["caption_theme"].apply(lambda x: x.split(",")[0])
df["main_meme_theme"] = df["meme_theme"].apply(lambda x: x.split(",")[0])

ct = pd.crosstab(df["main_theme"], df["main_meme_theme"])

fig, ax = plt.subplots(figsize=(12, 7))
sns.heatmap(ct, annot=True, fmt="d", cmap="Blues", linewidths=0.5, ax=ax)

ax.set_title("Caption Themes vs Meme Themes")
ax.set_xlabel("Meme Theme")
ax.set_ylabel("Caption Theme")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()

fig.savefig("outputs/heatmap.png", dpi=300, bbox_inches="tight")
plt.show()

display(Image(filename="outputs/heatmap.png"))
